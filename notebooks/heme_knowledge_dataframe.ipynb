# %% [markdown]
# # Dataframe
#
# This notebook merges all the BEL files contained in the curation folder and gives dataframe for all entity and interaction types in heme knowledge graph

# %%
import os
import pybel

from pybel.struct import union 
import pandas as pd
from pandas.plotting import table
import matplotlib.pyplot as plt

from pybel.struct.summary import count_functions, edge_summary

import heme_knowledge

# %%
HERE = os.path.abspath(os.path.dirname('__file__'))

BEL_DIRECTORY = os.path.abspath(os.path.join(HERE, os.pardir, 'curation', 'bel'))

def get_bel_files():
    """Return all bel files."""
    return [
        os.path.join(BEL_DIRECTORY, filename)
        for filename in os.listdir(BEL_DIRECTORY)
    ]

# %%
def get_files_in_folder(path):
    """Return the files in a given folder.
    :param path: folder path
    :return: file names in folder
    """
    return [
        file for file in os.listdir(path)
    ]

# %%
def get_bel_types(bel_path):
    """Get BEL node and edge type statistics.
    :param str path: path to BEL graph
    :return: count of all nodes and edges in a BEL graph
    :rtype: dict
    """
    bel_stats = {}
    bel_graph = pybel.from_path(bel_path)
    
    bel_stats['nodes'] = bel_graph.number_of_nodes()
    bel_stats['edges'] = bel_graph.number_of_edges()
    print(bel_stats)

    # Get count of all BEL function types
    bel_functions_dict = count_functions(bel_graph)
    bel_stats.update(bel_functions_dict)

    # Get count of all BEL edge types
    bel_edges_dict = edge_summary.count_relations(bel_graph)
    bel_stats.update(bel_edges_dict)

    return bel_stats

# %%
BEL_STATS_COLUMN_NAMES = {
    'nodes': 'Nodes',
    'edges': 'Edges',
    'Protein': 'Proteins',
    'Gene': 'Genes',
    'RNA': 'RNA Entities',
    'Complex': 'Complexes',
    'Abundance': 'Compounds',
    'BiologicalProcess': 'Biological Processes',
    'Pathology':'Pathology',
    'Reaction': 'Reactions',
    'increases': 'Increase Relations',
    'decreases': 'Decrease Relations',
    'association': 'Association Relations',
    'hasComponent': 'Component Edges',
    'hasVariant': 'Variant Edges',
    'hasReactant': 'Reactants Edges',
    'hasProduct': 'Products Edges',
    'positiveCorrelation':'Positive Correlation',
    'negativeCorrelation':'Negative Correlation',
    'causesNoChange':'CauseNoChange Relations',
    'directlyIncreases':'Directly Increase Relations'

}

# %%
def get_bel_stats(resource_folder):
    """Get all BEL node and edge type statistics.
    :param str resource_folder: path to BEL folder
    :return: count of all nodes and edges in all BEL graphs from one resource
    :rtype: dict
    """
    df = pd.DataFrame()
    
    files_list = get_files_in_folder(resource_folder)
    for file in files_list:
        pathway_names = []
        pathway_names.append(file)

        bel_statistics_dict = get_bel_types(os.path.join(resource_folder, file))

        all_bel_statistics = {
            BEL_STATS_COLUMN_NAMES[key]: value
            for key, value in bel_statistics_dict.items()
        }
        print(all_bel_statistics)

        # Add pathway statistic rows to DataFrame
        pathway_data = pd.DataFrame(
            all_bel_statistics,
            index=pathway_names,
            columns=BEL_STATS_COLUMN_NAMES.values(),
            dtype=int
        )

        df = df.append(pathway_data.fillna(0).astype(int))

    return df

# %%
heme_statistics_df = get_bel_stats(BEL_DIRECTORY)
# Out:
# {'nodes': 25, 'edges': 65}
# {'Nodes': 25, 'Edges': 65, 'Compounds': 8, 'Pathology': 5, 'Proteins': 6, 'Biological Processes': 4, 'Complexes': 1, 'Reactions': 1, 'Positive Correlation': 50, 'Negative Correlation': 10, 'Component Edges': 2, 'Reactants Edges': 2, 'Products Edges': 1}
# {'nodes': 55, 'edges': 133}
# {'Nodes': 55, 'Edges': 133, 'Compounds': 29, 'Proteins': 5, 'Pathology': 7, 'Reactions': 6, 'Complexes': 4, 'Biological Processes': 3, 'RNA Entities': 1, 'Positive Correlation': 60, 'Increase Relations': 24, 'Negative Correlation': 8, 'Decrease Relations': 16, 'Reactants Edges': 11, 'Products Edges': 6, 'Component Edges': 8}
# {'nodes': 13, 'edges': 21}
# {'Nodes': 13, 'Edges': 21, 'Compounds': 8, 'Biological Processes': 2, 'Proteins': 2, 'Complexes': 1, 'Increase Relations': 4, 'Positive Correlation': 4, 'Decrease Relations': 11, 'Component Edges': 2}
# {'nodes': 13, 'edges': 50}
# {'Nodes': 13, 'Edges': 50, 'Proteins': 4, 'Biological Processes': 2, 'Compounds': 7, 'Negative Correlation': 38, 'Positive Correlation': 10, 'CauseNoChange Relations': 2}
# {'nodes': 21, 'edges': 68}
# {'Nodes': 21, 'Edges': 68, 'Compounds': 4, 'Biological Processes': 2, 'Pathology': 4, 'Proteins': 11, 'Positive Correlation': 54, 'Increase Relations': 5, 'Negative Correlation': 8, 'Decrease Relations': 1}
# {'nodes': 23, 'edges': 33}
# {'Nodes': 23, 'Edges': 33, 'Proteins': 5, 'Compounds': 10, 'Reactions': 1, 'Pathology': 6, 'Complexes': 1, 'Decrease Relations': 10, 'Positive Correlation': 14, 'Increase Relations': 3, 'Reactants Edges': 3, 'Products Edges': 1, 'Component Edges': 2}
# {'nodes': 17, 'edges': 26}
# {'Nodes': 17, 'Edges': 26, 'Proteins': 6, 'Compounds': 6, 'Biological Processes': 4, 'Pathology': 1, 'Positive Correlation': 16, 'Decrease Relations': 4, 'Negative Correlation': 2, 'CauseNoChange Relations': 1, 'Increase Relations': 3}
# {'nodes': 9, 'edges': 13}
# {'Nodes': 9, 'Edges': 13, 'Pathology': 2, 'Compounds': 2, 'Proteins': 3, 'Complexes': 2, 'Positive Correlation': 8, 'Component Edges': 5}
# {'nodes': 10, 'edges': 17}
# {'Nodes': 10, 'Edges': 17, 'Genes': 1, 'Proteins': 7, 'Compounds': 1, 'Biological Processes': 1, 'Positive Correlation': 8, 'Increase Relations': 7, 'Decrease Relations': 2}
# {'nodes': 11, 'edges': 31}
# {'Nodes': 11, 'Edges': 31, 'Pathology': 3, 'Compounds': 4, 'Proteins': 4, 'Positive Correlation': 22, 'Increase Relations': 3, 'Negative Correlation': 6}
# {'nodes': 125, 'edges': 223}
# {'Nodes': 125, 'Edges': 223, 'Proteins': 39, 'Compounds': 36, 'Biological Processes': 21, 'Pathology': 23, 'Reactions': 3, 'Complexes': 3, 'Positive Correlation': 68, 'Decrease Relations': 28, 'Increase Relations': 101, 'Negative Correlation': 10, 'Reactants Edges': 4, 'Products Edges': 4, 'Variant Edges': 1, 'Component Edges': 6, 'CauseNoChange Relations': 1}
# {'nodes': 10, 'edges': 24}
# {'Nodes': 10, 'Edges': 24, 'Proteins': 2, 'Compounds': 6, 'Biological Processes': 1, 'Pathology': 1, 'Negative Correlation': 8, 'Positive Correlation': 10, 'Decrease Relations': 4, 'CauseNoChange Relations': 2}
# {'nodes': 25, 'edges': 45}
# {'Nodes': 25, 'Edges': 45, 'Proteins': 15, 'Compounds': 5, 'Pathology': 1, 'Complexes': 1, 'Biological Processes': 3, 'Negative Correlation': 12, 'Decrease Relations': 8, 'Positive Correlation': 8, 'Increase Relations': 11, 'Component Edges': 6}
# {'nodes': 115, 'edges': 268}
# {'Nodes': 115, 'Edges': 268, 'Pathology': 31, 'Compounds': 38, 'Biological Processes': 13, 'Proteins': 29, 'Complexes': 3, 'Reactions': 1, 'Positive Correlation': 106, 'Association Relations': 34, 'Negative Correlation': 10, 'Decrease Relations': 24, 'Increase Relations': 84, 'Component Edges': 6, 'Reactants Edges': 2, 'Products Edges': 2}
# {'nodes': 26, 'edges': 70}
# {'Nodes': 26, 'Edges': 70, 'Proteins': 4, 'Biological Processes': 8, 'Compounds': 10, 'Pathology': 2, 'Genes': 1, 'Complexes': 1, 'Positive Correlation': 42, 'Negative Correlation': 16, 'Increase Relations': 5, 'Decrease Relations': 5, 'Component Edges': 2}
# {'nodes': 13, 'edges': 36}
# {'Nodes': 13, 'Edges': 36, 'Proteins': 2, 'Compounds': 7, 'Pathology': 2, 'Biological Processes': 2, 'Negative Correlation': 4, 'Positive Correlation': 32}
# {'nodes': 11, 'edges': 22}
# {'Nodes': 11, 'Edges': 22, 'Proteins': 4, 'Pathology': 3, 'Compounds': 2, 'Genes': 1, 'Complexes': 1, 'Positive Correlation': 10, 'Negative Correlation': 8, 'CauseNoChange Relations': 1, 'Decrease Relations': 1, 'Component Edges': 2}
# {'nodes': 21, 'edges': 40}
# {'Nodes': 21, 'Edges': 40, 'Pathology': 4, 'Compounds': 7, 'Proteins': 6, 'Complexes': 2, 'Biological Processes': 2, 'Positive Correlation': 18, 'Negative Correlation': 10, 'Increase Relations': 5, 'Decrease Relations': 2, 'Component Edges': 5}
# {'nodes': 12, 'edges': 13}
# {'Nodes': 12, 'Edges': 13, 'Proteins': 3, 'Pathology': 6, 'Compounds': 2, 'Biological Processes': 1, 'Increase Relations': 9, 'Decrease Relations': 2, 'Negative Correlation': 2}
# {'nodes': 50, 'edges': 130}
# {'Nodes': 50, 'Edges': 130, 'Biological Processes': 3, 'Proteins': 29, 'Compounds': 11, 'RNA Entities': 2, 'Complexes': 3, 'Pathology': 2, 'Positive Correlation': 26, 'Increase Relations': 33, 'Decrease Relations': 40, 'Negative Correlation': 26, 'CauseNoChange Relations': 1, 'Component Edges': 4}
# {'nodes': 34, 'edges': 67}
# {'Nodes': 34, 'Edges': 67, 'Compounds': 9, 'Biological Processes': 4, 'Pathology': 4, 'Proteins': 17, 'Positive Correlation': 36, 'Decrease Relations': 8, 'Increase Relations': 13, 'Negative Correlation': 8, 'Association Relations': 2}
# {'nodes': 60, 'edges': 85}
# {'Nodes': 60, 'Edges': 85, 'Pathology': 9, 'Proteins': 23, 'Compounds': 12, 'Biological Processes': 13, 'Complexes': 3, 'Positive Correlation': 8, 'Increase Relations': 39, 'Decrease Relations': 21, 'Negative Correlation': 6, 'CauseNoChange Relations': 3, 'Component Edges': 6, 'Association Relations': 2}
# {'nodes': 20, 'edges': 33}
# {'Nodes': 20, 'Edges': 33, 'Pathology': 2, 'Proteins': 7, 'Compounds': 7, 'Biological Processes': 3, 'Complexes': 1, 'Positive Correlation': 8, 'Increase Relations': 12, 'CauseNoChange Relations': 2, 'Decrease Relations': 6, 'Negative Correlation': 4, 'Component Edges': 1}
# {'nodes': 18, 'edges': 72}
# {'Nodes': 18, 'Edges': 72, 'Pathology': 3, 'Biological Processes': 4, 'Compounds': 5, 'Proteins': 5, 'Complexes': 1, 'Positive Correlation': 40, 'Negative Correlation': 28, 'Increase Relations': 1, 'Decrease Relations': 1, 'Component Edges': 2}
# {'nodes': 30, 'edges': 45}
# {'Nodes': 30, 'Edges': 45, 'Proteins': 2, 'Reactions': 4, 'Compounds': 14, 'Biological Processes': 7, 'Pathology': 3, 'Increase Relations': 16, 'Decrease Relations': 20, 'Reactants Edges': 5, 'Products Edges': 4}
# {'nodes': 31, 'edges': 107}
# {'Nodes': 31, 'Edges': 107, 'Proteins': 14, 'Compounds': 6, 'Pathology': 4, 'Biological Processes': 3, 'Complexes': 3, 'RNA Entities': 1, 'Negative Correlation': 32, 'Positive Correlation': 64, 'Increase Relations': 1, 'Component Edges': 6, 'CauseNoChange Relations': 4}
# {'nodes': 16, 'edges': 50}
# {'Nodes': 16, 'Edges': 50, 'Proteins': 4, 'Compounds': 6, 'Biological Processes': 5, 'Complexes': 1, 'Increase Relations': 2, 'Positive Correlation': 28, 'Negative Correlation': 16, 'Decrease Relations': 2, 'Component Edges': 2}
# {'nodes': 13, 'edges': 33}
# {'Nodes': 13, 'Edges': 33, 'Pathology': 1, 'Proteins': 4, 'Compounds': 5, 'Biological Processes': 1, 'Complexes': 2, 'Positive Correlation': 6, 'Increase Relations': 7, 'Decrease Relations': 14, 'Component Edges': 4, 'CauseNoChange Relations': 2}
# {'nodes': 37, 'edges': 77}
# {'Nodes': 37, 'Edges': 77, 'Proteins': 15, 'Biological Processes': 4, 'Pathology': 3, 'Compounds': 7, 'RNA Entities': 8, 'Positive Correlation': 46, 'Decrease Relations': 1, 'Negative Correlation': 28, 'Increase Relations': 2}
# {'nodes': 31, 'edges': 42}
# {'Nodes': 31, 'Edges': 42, 'Proteins': 8, 'Compounds': 6, 'Pathology': 7, 'Biological Processes': 7, 'Complexes': 2, 'Reactions': 1, 'Decrease Relations': 18, 'Increase Relations': 18, 'Component Edges': 4, 'Reactants Edges': 1, 'Products Edges': 1}
# {'nodes': 41, 'edges': 65}
# {'Nodes': 41, 'Edges': 65, 'Compounds': 8, 'Pathology': 5, 'Biological Processes': 7, 'Proteins': 11, 'RNA Entities': 8, 'Complexes': 1, 'Genes': 1, 'Positive Correlation': 22, 'Increase Relations': 11, 'Decrease Relations': 21, 'Negative Correlation': 6, 'Component Edges': 3, 'Variant Edges': 2}
# {'nodes': 64, 'edges': 118}
# {'Nodes': 64, 'Edges': 118, 'Compounds': 23, 'Biological Processes': 21, 'Pathology': 14, 'Proteins': 6, 'Association Relations': 6, 'Increase Relations': 39, 'Positive Correlation': 52, 'Negative Correlation': 4, 'Decrease Relations': 17}
# {'nodes': 26, 'edges': 50}
# {'Nodes': 26, 'Edges': 50, 'Compounds': 3, 'Biological Processes': 5, 'Proteins': 12, 'RNA Entities': 4, 'Complexes': 1, 'Pathology': 1, 'Positive Correlation': 18, 'Increase Relations': 9, 'Decrease Relations': 13, 'CauseNoChange Relations': 5, 'Negative Correlation': 2, 'Variant Edges': 1, 'Component Edges': 2}
# {'nodes': 24, 'edges': 64}
# {'Nodes': 24, 'Edges': 64, 'Compounds': 11, 'Proteins': 6, 'Complexes': 6, 'RNA Entities': 1, 'Positive Correlation': 22, 'Decrease Relations': 12, 'Increase Relations': 6, 'Negative Correlation': 10, 'Component Edges': 12, 'CauseNoChange Relations': 2}
# {'nodes': 23, 'edges': 45}
# {'Nodes': 23, 'Edges': 45, 'Pathology': 8, 'Compounds': 6, 'Biological Processes': 2, 'Proteins': 3, 'Complexes': 1, 'RNA Entities': 3, 'Positive Correlation': 20, 'Decrease Relations': 2, 'Increase Relations': 19, 'CauseNoChange Relations': 2, 'Component Edges': 2}
# {'nodes': 15, 'edges': 34}
# {'Nodes': 15, 'Edges': 34, 'Compounds': 6, 'Pathology': 3, 'Biological Processes': 2, 'Proteins': 4, 'Increase Relations': 1, 'Positive Correlation': 28, 'Negative Correlation': 4, 'Decrease Relations': 1}
# {'nodes': 16, 'edges': 35}
# {'Nodes': 16, 'Edges': 35, 'Compounds': 5, 'Biological Processes': 3, 'Pathology': 3, 'Proteins': 5, 'Positive Correlation': 10, 'Increase Relations': 6, 'Decrease Relations': 17, 'CauseNoChange Relations': 2}
# {'nodes': 16, 'edges': 64}
# {'Nodes': 16, 'Edges': 64, 'Proteins': 2, 'Compounds': 6, 'Pathology': 6, 'Biological Processes': 2, 'Negative Correlation': 18, 'Positive Correlation': 46}
# {'nodes': 20, 'edges': 36}
# {'Nodes': 20, 'Edges': 36, 'Compounds': 7, 'Proteins': 7, 'Biological Processes': 5, 'Complexes': 1, 'Decrease Relations': 4, 'Positive Correlation': 20, 'Increase Relations': 6, 'Component Edges': 2, 'Negative Correlation': 2, 'CauseNoChange Relations': 2}
# {'nodes': 27, 'edges': 88}
# {'Nodes': 27, 'Edges': 88, 'Pathology': 7, 'Proteins': 12, 'Compounds': 5, 'Biological Processes': 2, 'Complexes': 1, 'Positive Correlation': 36, 'Negative Correlation': 48, 'Component Edges': 2, 'CauseNoChange Relations': 2}
# {'nodes': 49, 'edges': 117}
# {'Nodes': 49, 'Edges': 117, 'Proteins': 13, 'Pathology': 15, 'Compounds': 13, 'Biological Processes': 6, 'Reactions': 2, 'Increase Relations': 24, 'Positive Correlation': 64, 'CauseNoChange Relations': 1, 'Variant Edges': 1, 'Negative Correlation': 14, 'Decrease Relations': 7, 'Reactants Edges': 3, 'Products Edges': 3}
# {'nodes': 105, 'edges': 175}
# {'Nodes': 105, 'Edges': 175, 'Biological Processes': 24, 'Pathology': 32, 'Compounds': 36, 'Proteins': 10, 'Complexes': 3, 'Positive Correlation': 82, 'Increase Relations': 54, 'Association Relations': 12, 'Negative Correlation': 8, 'Decrease Relations': 10, 'Directly Increase Relations': 1, 'Component Edges': 4, 'CauseNoChange Relations': 4}
# {'nodes': 13, 'edges': 20}
# {'Nodes': 13, 'Edges': 20, 'Biological Processes': 3, 'Compounds': 3, 'Proteins': 5, 'RNA Entities': 1, 'Pathology': 1, 'Positive Correlation': 18, 'Increase Relations': 2}
# {'nodes': 28, 'edges': 33}
# {'Nodes': 28, 'Edges': 33, 'Compounds': 12, 'Proteins': 6, 'Biological Processes': 5, 'Pathology': 3, 'Complexes': 2, 'Increase Relations': 20, 'Decrease Relations': 9, 'Component Edges': 4}
# {'nodes': 23, 'edges': 66}
# {'Nodes': 23, 'Edges': 66, 'Proteins': 4, 'Compounds': 10, 'Biological Processes': 5, 'Complexes': 3, 'Pathology': 1, 'Decrease Relations': 12, 'Positive Correlation': 28, 'Variant Edges': 2, 'Negative Correlation': 16, 'Component Edges': 7, 'Increase Relations': 1}
# {'nodes': 28, 'edges': 72}
# {'Nodes': 28, 'Edges': 72, 'Pathology': 11, 'Biological Processes': 6, 'Compounds': 5, 'Proteins': 5, 'Complexes': 1, 'Positive Correlation': 54, 'Increase Relations': 9, 'Component Edges': 3, 'Decrease Relations': 6}

# %%
heme_statistics_df
# Out:
#                    Nodes  Edges  Proteins  Genes  RNA Entities  Complexes  \
# heme_19276082.bel     25     65         6      0             0          1
# heme_20378845.bel     55    133         5      0             1          4
# heme_22954673.bel     13     21         2      0             0          1
# heme_23215741.bel     13     50         4      0             0          0
# heme_24464629.bel     21     68        11      0             0          0
# heme_24486321.bel     23     33         5      0             0          1
# heme_24489717.bel     17     26         6      0             0          0
# heme_24553061.bel      9     13         3      0             0          2
# heme_24630724.bel     10     17         7      1             0          0
# heme_24667910.bel     11     31         4      0             0          0
# heme_24904418.bel    125    223        39      0             0          3
# heme_25264713.bel     10     24         2      0             0          0
# heme_25301065.bel     25     45        15      0             0          1
# heme_25307023.bel    115    268        29      0             0          3
# heme_25411909.bel     26     70         4      1             0          1
# heme_26202471.bel     13     36         2      0             0          0
# heme_26337933.bel     11     22         4      1             0          1
# heme_26368565.bel     21     40         6      0             0          2
# heme_26475040.bel     12     13         3      0             0          0
# heme_26675351.bel     50    130        29      0             2          3
# heme_26794659.bel     34     67        17      0             0          0
# heme_26875449.bel     60     85        23      0             0          3
# heme_26974230.bel     20     33         7      0             0          1
# heme_27125525.bel     18     72         5      0             0          1
# heme_27308950.bel     30     45         2      0             0          0
# heme_27515135.bel     31    107        14      0             1          3
# heme_27798618.bel     16     50         4      0             0          1
# heme_28088643.bel     13     33         4      0             0          2
# heme_28143953.bel     37     77        15      0             8          0
# heme_28314763.bel     31     42         8      0             0          2
# heme_28400318.bel     41     65        11      1             8          1
# heme_28458720.bel     64    118         6      0             0          0
# heme_28716864.bel     26     50        12      0             4          1
# heme_29212341.bel     24     64         6      0             1          6
# heme_29351418.bel     23     45         3      0             3          1
# heme_29522519.bel     15     34         4      0             0          0
